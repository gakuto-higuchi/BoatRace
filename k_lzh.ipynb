# %%
START_DATE = "2022-07-01"
END_DATE = "2022-07-31"

SAVE_DIR = "/Users/higuchirakuhi/Boat_Race_git/BoatRace/results_lzh/"

INTERVAL = 3

FIXED_URL = "http://www1.mbrace.or.jp/od2/K/"

from time import sleep
from requests import get
from datetime import datetime as dt
from datetime import timedelta as td
from os import makedirs

print("作業を開始します。")
makedirs(SAVE_DIR, exist_ok=True)

start_date = dt.strptime(START_DATE, "%Y-%m-%d")
end_date = dt.strptime(END_DATE, "%Y-%m-%d")
days_num = (end_date - start_date).days + 1

date_list = []

for i in range(days_num):
    target_date = start_date + td(days = i)
    
    date_list.append(target_date.strftime("%Y%m%d"))
    
for date in date_list:
    yyyymm = date[0:4] + date[4:6]
    yymmdd = date[2:4] + date[4:6] + date[6:8]
    
    variable_url = FIXED_URL + yyyymm + "/k" + yymmdd + ".lzh"
    file_name = 'K' + yymmdd + ".lzh"
    
    r = get(variable_url)
    
    if r.status_code == 200:
        f = open(SAVE_DIR + file_name, 'wb')
        f.write(r.content)
        f.close()
        print(variable_url + "をダウンロードしました。")
        
    else:
        print(variable_url + "のダウンロードに失敗しました。")
        
    sleep(INTERVAL)
    
print("作業を終了しました。")
# Out:
# 作業を開始します。
# http://www1.mbrace.or.jp/od2/K/202207/k220701.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220702.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220703.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220704.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220705.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220706.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220707.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220708.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220709.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220710.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220711.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220712.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220713.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220714.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220715.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220716.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220717.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220718.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220719.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220720.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220721.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220722.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220723.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220724.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220725.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220726.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220727.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220728.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220729.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220730.lzhをダウンロードしました。
# 作業を終了しました。
# http://www1.mbrace.or.jp/od2/K/202207/k220731.lzhをダウンロードしました。
# 作業を終了しました。

# %%
LZH_FILE_DIR ="/Users/higuchirakuhi/Boat_Race_git/BoatRace/results_lzh/"
TEXT_FILE_DIR ="/Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/"

import lhafile
import os
import re
print("作業を開始します。")
os.makedirs(TEXT_FILE_DIR, exist_ok=True)
lzh_file_list = os.listdir(LZH_FILE_DIR)

for lzh_file_name in lzh_file_list:
    
    if re.search(".lzh", lzh_file_name):
        
        file = lhafile.Lhafile(LZH_FILE_DIR + lzh_file_name)
        
        info = file.infolist()
        file_name = info[0].filename
        
        f = open(TEXT_FILE_DIR + file_name, 'wb')
        f.write(file.read(file_name))
        f.close()
        
        print(TEXT_FILE_DIR + lzh_file_name + "を解凍しました。")
        
print("作業を終了しました。")
# Out:
# 作業を開始します。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220714.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220728.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220729.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220701.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220715.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220703.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220717.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220716.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220702.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220706.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220712.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220713.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220707.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220711.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220705.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220704.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220710.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220721.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220709.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220708.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220720.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220722.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220723.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220727.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220726.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220718.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220730.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220724.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220725.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220731.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/results_txt/K220719.lzhを解凍しました。
# 作業を終了しました。
