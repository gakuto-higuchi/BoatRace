# %%
import pandas as pd
df = pd.read_csv("/Users/higuchirakuhi/Boat_Race_git/BoatRace/results_csv/results_20160401-20220731.csv")
# Out:
# /Users/higuchirakuhi/miniforge3/envs/ds_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3361: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df = df[~df['in'].astype(str).str.contains('\D')]
df = df[~df['order'].astype(str).str.contains('\D')]

# %%
df.head(6)
# Out:
#         race_code date   race_date place round  order  position  number  \
# 0  20210326KRT01R  第4日  2021/03/26    唐津    1R      1         1    4324
# 1  20210326KRT01R  第4日  2021/03/26    唐津    1R      2         6    4949
# 2  20210326KRT01R  第4日  2021/03/26    唐津    1R      3         5    4994
# 3  20210326KRT01R  第4日  2021/03/26    唐津    1R      4         4    3488
# 4  20210326KRT01R  第4日  2021/03/26    唐津    1R      5         2    4899
# 5  20210326KRT01R  第4日  2021/03/26    唐津    1R      6         3    4121
#
#     name  motor  boat  display  in st_time race_time type weather wind  \
# 0  海野康志郎     48    48     6.62   1    0.14    1.49.8   逃げ       晴   南西
# 1   横田貴満     61    49     6.63   6    0.11    1.50.6   逃げ       晴   南西
# 2   山本梨菜     51    87     6.62   5    0.08    1.52.2   逃げ       晴   南西
# 3   柳田英明     70    84     6.71   4    0.05    1.52.4   逃げ       晴   南西
# 4   占部一真     68    57     6.67   2    0.15    1.54.9   逃げ       晴   南西
# ...

# %%
#もとのcsvfileに戻す
df.to_csv("/Users/higuchirakuhi/Boat_Race_git/BoatRace/results_csv/results_20160401-20220731.csv",index=False)

# %%
df.to_csv("/Users/higuchirakuhi/Boat_Race_git/BoatRace/lightgbm_csv/lightgbm.csv",index=False)
