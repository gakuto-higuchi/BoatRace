# %%
START_DATE = "2022-07-01"
END_DATE = "2022-07-31"

SAVE_DIR = "/Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_lzh/"

INTERVAL= 3

FIXED_URL = "https://www1.mbrace.or.jp/od2/B/"

from datetime import datetime as dt
from datetime import timedelta as td
from requests import get
from os import makedirs
from time import sleep
print("作業を開始します。")

makedirs(SAVE_DIR, exist_ok=True)

start_date = dt.strptime(START_DATE, "%Y-%m-%d")
end_date = dt.strptime(END_DATE, "%Y-%m-%d")

days_num = (end_date - start_date).days + 1

date_list = []

for d in range(days_num):
    target_date = start_date + td(days=d)
    
    date_list.append(target_date.strftime("%Y%m%d"))
    
for date in date_list:
    yyyymm = date[0:4] + date[4:6]
    yymmdd = date[2:4] + date[4:6] + date[6:8]
    
    variable_url = FIXED_URL + yyyymm + "/b" + yymmdd + ".lzh"
    file_name = "b" + yymmdd + ".lzh"
    
    r = get(variable_url)
    
    if r.status_code == 200:
        f = open(SAVE_DIR + file_name, "wb")
        f.write(r.content)
        f.close()
        print(variable_url + "をダウンロードしました。")
        
    else:
        print(variable_url + "をダウンロードに失敗しました。")
        
    sleep(INTERVAL)
    
print("作業を終了しました。")
# Out:
# 作業を開始します。
# https://www1.mbrace.or.jp/od2/B/202207/b220701.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220702.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220703.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220704.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220705.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220706.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220707.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220708.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220709.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220710.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220711.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220712.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220713.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220714.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220715.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220716.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220717.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220718.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220719.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220720.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220721.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220722.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220723.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220724.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220725.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220726.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220727.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220728.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220729.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220730.lzhをダウンロードしました。
# https://www1.mbrace.or.jp/od2/B/202207/b220731.lzhをダウンロードしました。
# 作業を終了しました。

# %%
LZH_FILE_DIR = "/Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_lzh/"

TEXT_FILE_DIR = "/Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/"

import lhafile
import os
import re
print("作業を開始します。")
os.makedirs(TEXT_FILE_DIR, exist_ok=True)
lzh_file_list = os.listdir(LZH_FILE_DIR)

for lzh_file_name in lzh_file_list:
    
    if re.search(".lzh",lzh_file_name):
        
        file = lhafile.Lhafile(LZH_FILE_DIR + lzh_file_name)
        
        info = file.infolist()
        file_name = info[0].filename
        
        f = open(TEXT_FILE_DIR + file_name, "wb")
        f.write(file.read(file_name))
        f.close
        
        print(TEXT_FILE_DIR + lzh_file_name + "を解凍しました。")
        
print("作業を終了しました。")
# Out:
# 作業を開始します。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220718.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220724.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220730.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220731.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220725.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220719.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220727.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220726.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220722.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220723.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220721.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220709.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220708.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220720.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220705.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220711.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220710.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220704.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220712.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220706.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220707.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220713.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220717.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220703.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220702.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220716.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220714.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220728.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220729.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220715.lzhを解凍しました。
# /Users/higuchirakuhi/Boat_Race_git/BoatRace/timetable_txt/b220701.lzhを解凍しました。
# 作業を終了しました。
